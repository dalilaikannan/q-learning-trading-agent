# %%
#Install and import
# !pip install yfinance hmmlearn pandas numpy matplotlib seaborn

import yfinance as yf
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
# Out:
# Requirement already satisfied: yfinance in /opt/anaconda3/lib/python3.12/site-packages (0.2.66)
# Requirement already satisfied: hmmlearn in /opt/anaconda3/lib/python3.12/site-packages (0.3.3)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/dharanaalilaikannan/.local/lib/python3.12/site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from hmmlearn) (1.5.1)
# Requirement already satisfied: scipy>=0.19 in /opt/anaconda3/lib/python3.12/site-packages (from hmmlearn) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dharanaalilaikannan/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dharanaalilaikannan/.local/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/dharanaalilaikannan/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.5.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)

# %% [markdown]
# ## Download the necessary data.

# %%
vix = yf.download("^VIX", start="2000-01-01", auto_adjust="True")
spy = yf.download("SPY", start="2000-01-01", auto_adjust="True")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Grab the necessary columns, clean, and calculate our log returns for SPY

# %%
spy_close = spy["Close"].dropna()
vix_close = vix["Close"].dropna()

log_returns = np.log(spy_close / spy_close.shift(1)).dropna()

# %% [markdown]
# ## Data Overview
#
# ### SPY Log Returns (2000–Present)
# - **Mean**: 0.0003 — small positive drift, reflects long-term upward trend
# - **Std**: 0.012 — ~1.2% average daily volatility
# - **Min**: -0.116 — worst single day crash (likely March 2020 or Oct 2008)
# - **Max**: 0.136 — largest single day gain (likely post-crash recovery)
#
# ### VIX (2000–Present)
# - **Mean**: 19.8 — historically anything below 20 is considered calm
# - **Min**: 9.14 — extremely low fear, deep bull market conditions
# - **Max**: 82.69 — COVID March 2020, peak panic
# - **75th percentile**: 23.2 — 75% of days VIX was below 23, so above this is elevated fear

# %%
print(log_returns.describe())
print()
print(vix_close.describe())
# Out:
# Ticker          SPY
# count   6621.000000
# mean       0.000312
# std        0.012184
# min       -0.115887
# 25%       -0.004607
# 50%        0.000690
# 75%        0.005971
# max        0.135577
#
# Ticker         ^VIX
# count   6622.000000
# mean      19.843393
# std        8.326994
# min        9.140000
# 25%       14.020000
# 50%       17.830000
# 75%       23.227499
# max       82.690002

# %% [markdown]
# ## Plotting SPY & VIX Closing Prices

# %%
plt.plot(spy_close)
plt.title('SPY Closing Prices : Jan 1st 2000 - Present Day')
plt.show()

plt.plot(vix_close)
plt.title('VIX Closing Prices : Jan 1st 2000 - Present Day')
plt.show()

# %% [markdown]
# ## Create / Clean the Data Frame

# %%
df = pd.concat([log_returns, vix_close], axis=1)
df_cleaned = df.dropna()
df_cleaned.shape
# Out:
# (6621, 2)

# %% [markdown]
# ## Normalizing Values
#
# Because the values of VIX are much higher than the ones in SPY, here we standardize the values to be centered around a mean of 0 and a standard deviation of 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_cleaned)
print(df_scaled)
# Out:
# [[-3.29999579  0.86074461]
#  [ 0.12111337  0.78868826]
#  [-1.35555305  0.7070244 ]
#  ...
#  [-0.03829004 -0.12402503]
#  [ 0.78705575 -0.35460523]
#  [ 0.20137933 -0.3425958 ]]

# %%
from hmmlearn import hmm
import collections

model = hmm.GaussianHMM(n_components=3, covariance_type="diag", n_iter=100, random_state=42)

model.fit(df_scaled)
states = model.predict(df_scaled)

print(states)
print(collections.Counter(states))
print(model.means_)
# Out:
# [2 2 2 ... 0 0 0]
# Counter({0: 2681, 1: 2356, 2: 1584})
# [[ 0.0086698  -0.09113955]
#  [ 0.05918689 -0.8083915 ]
#  [-0.10182102  1.34442276]]

# %%
spy_aligned = spy_close.loc[df_cleaned.index]
print(spy_aligned.shape)

colors = [{0: "green", 1: "gray", 2: "red"}[s] for s in states]
print(colors[:5])

plt.scatter(df_cleaned.index, spy_aligned, c=colors, s=1)
plt.title("SPY Market Regimes")
plt.xlabel("Date")
plt.ylabel("SPY Price")
plt.show()

df_cleaned
# Out:
# (6621, 1)
# ['red', 'red', 'red', 'red', 'green']
# Ticker           SPY       ^VIX
# Date
# 2000-01-04 -0.039891  27.010000
# 2000-01-05  0.001787  26.410000
# 2000-01-06 -0.016202  25.730000
# 2000-01-07  0.056453  21.719999
# 2000-01-10  0.003424  21.709999
# ...              ...        ...
# 2026-04-27  0.001721  18.020000
# 2026-04-28 -0.004878  17.830000
# 2026-04-29 -0.000155  18.809999
# 2026-04-30  0.009900  16.889999
# 2026-05-01  0.002765  16.990000
#
# [6621 rows x 2 columns]

# %% [markdown]
# # Feature Engineering
#
# Discretized Log returns: [-∞, -0.0046, 0.0060, ∞]
#
# Decretized VIX: [-∞, 14.01, 23.20, ∞]
#
# Labels: ['low', 'medium', 'high']
#
# dataframe with these five columns — log_return, vix, regime, return_bin, vix_bin.

# %%
log_return = df_cleaned['SPY']
vix = df_cleaned['^VIX']
regime = pd.Categorical.from_codes(states, categories=["bull", "sideways", "bear"])
return_bin = pd.cut(df_cleaned['SPY'], bins=[-np.inf, -0.0046, 0.0060, np.inf], labels=["low", "medium", "high"])
vix_bin = pd.cut(df_cleaned['^VIX'], bins=[-np.inf, 14.01, 23.20, np.inf], labels=["low", "neutral", "high"])

df_q_info = pd.DataFrame({
    'log_return': log_return,
    'volatility' : vix,
    'regime': regime,
    'return_disc': return_bin,
    'volatility_disc': vix_bin,
    'spy_close': spy_aligned.squeeze(),
    # market momentum
})

df_q_info
# Out:
#             log_return  volatility regime return_disc volatility_disc  \
# Date
# 2000-01-04   -0.039891   27.010000   bear         low            high
# 2000-01-05    0.001787   26.410000   bear      medium            high
# 2000-01-06   -0.016202   25.730000   bear         low            high
# 2000-01-07    0.056453   21.719999   bear        high         neutral
# 2000-01-10    0.003424   21.709999   bull      medium         neutral
# ...                ...         ...    ...         ...             ...
# 2026-04-27    0.001721   18.020000   bull      medium         neutral
# 2026-04-28   -0.004878   17.830000   bull         low         neutral
# 2026-04-29   -0.000155   18.809999   bull      medium         neutral
# 2026-04-30    0.009900   16.889999   bull        high         neutral
# 2026-05-01    0.002765   16.990000   bull      medium         neutral
#
#              spy_close
# Date
# 2000-01-04   87.794502
# 2000-01-05   87.951569
# 2000-01-06   86.538017
# 2000-01-07   91.563873
# 2000-01-10   91.877937
# ...                ...
# 2026-04-27  715.169983
# 2026-04-28  711.690002
# 2026-04-29  711.580017
# 2026-04-30  718.659973
# 2026-05-01  720.650024
#
# [6621 rows x 6 columns]

# %% [markdown]
# In this chunk of code, I'm initializing my q table. It'll store the rewards I can gain from taking a specific action from each state to end up in another.

# %%
epsilon = 1.0
decay = 0.999
alpha = 0.5
money = 1000
num_shares = 0

# %%
q_table = {}
regimes = ["bull", "sideways", "bear"]
return_bins = ["low", "medium", "high"]
vix_bins = ["low", "neutral", "high"]
actions = ['buy', 'sell', 'hold']

for r in regimes:
    for rb in return_bins:
        for vb in vix_bins:
            temp = (r, rb, vb)
            q_table[temp] = [0.0, 0.0, 0.0]

q_table
# Out:
# {('bull', 'low', 'low'): [0.0, 0.0, 0.0],
#  ('bull', 'low', 'neutral'): [0.0, 0.0, 0.0],
#  ('bull', 'low', 'high'): [0.0, 0.0, 0.0],
#  ('bull', 'medium', 'low'): [0.0, 0.0, 0.0],
#  ('bull', 'medium', 'neutral'): [0.0, 0.0, 0.0],
#  ('bull', 'medium', 'high'): [0.0, 0.0, 0.0],
#  ('bull', 'high', 'low'): [0.0, 0.0, 0.0],
#  ('bull', 'high', 'neutral'): [0.0, 0.0, 0.0],
#  ('bull', 'high', 'high'): [0.0, 0.0, 0.0],
#  ('sideways', 'low', 'low'): [0.0, 0.0, 0.0],
#  ('sideways', 'low', 'neutral'): [0.0, 0.0, 0.0],
#  ('sideways', 'low', 'high'): [0.0, 0.0, 0.0],
#  ('sideways', 'medium', 'low'): [0.0, 0.0, 0.0],
#  ('sideways', 'medium', 'neutral'): [0.0, 0.0, 0.0],
#  ('sideways', 'medium', 'high'): [0.0, 0.0, 0.0],
#  ('sideways', 'high', 'low'): [0.0, 0.0, 0.0],
#  ('sideways', 'high', 'neutral'): [0.0, 0.0, 0.0],
#  ('sideways', 'high', 'high'): [0.0, 0.0, 0.0],
#  ('bear', 'low', 'low'): [0.0, 0.0, 0.0],
#  ('bear', 'low', 'neutral'): [0.0, 0.0, 0.0],
#  ('bear', 'low', 'high'): [0.0, 0.0, 0.0],
#  ('bear', 'medium', 'low'): [0.0, 0.0, 0.0],
#  ('bear', 'medium', 'neutral'): [0.0, 0.0, 0.0],
#  ('bear', 'medium', 'high'): [0.0, 0.0, 0.0],
#  ('bear', 'high', 'low'): [0.0, 0.0, 0.0],
#  ('bear', 'high', 'neutral'): [0.0, 0.0, 0.0],
#  ('bear', 'high', 'high'): [0.0, 0.0, 0.0]}

# %%
for row in df_q_info.itertuples(index=False):
    current_state = (row.regime, row.return_disc, row.volatility_disc)
    compare = random.random()
    current_stock_price = row.spy_close

    # e-greedy policy
    if compare < epsilon :
        next_action = random.choice(actions)
        epsilon = epsilon * decay # decay epsilon everytime we explore by multiplying by the decay constant
    else :
        next_action = actions[np.argmax(q_table[current_state])]
    
    # take an action
    if next_action == 'buy' and money > current_stock_price:
        shares_to_buy = math.floor(money / current_stock_price)
        money -= current_stock_price * shares_to_buy
        num_shares += shares_to_buy 
        print(f"{money:.2f} + buy {shares_to_buy} shares")
        
    elif next_action == 'sell' and num_shares > 0:
        money += num_shares * current_stock_price
        num_shares = 0
        print(f"{money:.2f} + sell")
        
    elif next_action == 'hold':
        print("do nothing")
# Out:
# do nothing
# 48.08 + buy 11 shares
# 1055.28 + sell
# do nothing
# 66.65 + buy 11 shares
# do nothing
# 1074.29 + sell
# do nothing
# do nothing
# 76.16 + buy 11 shares
# 1057.01 + sell
# 87.82 + buy 11 shares
# 1026.78 + sell
# do nothing
# do nothing
# 37.28 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 1012.20 + sell
# 51.65 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 976.35 + sell
# do nothing
# 1.11 + buy 11 shares
# do nothing
# 946.98 + sell
# do nothing
# do nothing
# do nothing
# 2.84 + buy 11 shares
# do nothing
# do nothing
# 1036.42 + sell
# do nothing
# 74.96 + buy 10 shares
# 1042.13 + sell
# 85.19 + buy 10 shares
# 1036.61 + sell
# do nothing
# 89.52 + buy 10 shares
# 1042.13 + sell
# do nothing
# 0.10 + buy 11 shares
# do nothing
# 942.32 + sell
# 55.84 + buy 10 shares
# 965.74 + sell
# 64.31 + buy 10 shares
# 960.23 + sell
# 27.11 + buy 10 shares
# do nothing
# do nothing
# 953.34 + sell
# 45.61 + buy 10 shares
# 932.08 + sell
# do nothing
# 28.09 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 897.25 + sell
# 13.92 + buy 10 shares
# do nothing
# 911.42 + sell
# 11.95 + buy 10 shares
# 927.17 + sell
# 89.13 + buy 9 shares
# do nothing
# 919.37 + sell
# 83.37 + buy 9 shares
# 914.32 + sell
# do nothing
# 76.29 + buy 9 shares
# 909.19 + sell
# 65.63 + buy 9 shares
# 906.17 + sell
# 65.99 + buy 9 shares
# do nothing
# do nothing
# 885.22 + sell
# 59.77 + buy 9 shares
# do nothing
# 901.20 + sell
# do nothing
# 59.42 + buy 9 shares
# 906.71 + sell
# 55.69 + buy 9 shares
# do nothing
# 911.50 + sell
# 72.38 + buy 9 shares
# do nothing
# 879.72 + sell
# 67.23 + buy 9 shares
# 888.77 + sell
# do nothing
# 47.16 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 900.49 + sell
# do nothing
# 43.44 + buy 9 shares
# 903.16 + sell
# 43.79 + buy 9 shares
# 909.37 + sell
# 59.59 + buy 9 shares
# 909.55 + sell
# 65.81 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 891.11 + sell
# do nothing
# do nothing
# do nothing
# 75.69 + buy 9 shares
# 901.61 + sell
# do nothing
# 89.93 + buy 9 shares
# 908.37 + sell
# do nothing
# do nothing
# 36.96 + buy 10 shares
# 879.50 + sell
# do nothing
# 4.92 + buy 10 shares
# 854.58 + sell
# do nothing
# 78.14 + buy 9 shares
# do nothing
# 871.49 + sell
# 71.02 + buy 9 shares
# 882.52 + sell
# do nothing
# 69.24 + buy 9 shares
# do nothing
# 869.89 + sell
# 72.26 + buy 9 shares
# do nothing
# 864.72 + sell
# 69.77 + buy 9 shares
# do nothing
# 848.08 + sell
# do nothing
# 80.01 + buy 9 shares
# 854.84 + sell
# do nothing
# 10.33 + buy 10 shares
# 854.25 + sell
# 82.35 + buy 9 shares
# do nothing
# 847.93 + sell
# 16.50 + buy 10 shares
# 841.88 + sell
# do nothing
# 1.72 + buy 10 shares
# do nothing
# 858.74 + sell
# do nothing
# 38.62 + buy 10 shares
# do nothing
# 877.39 + sell
# 37.83 + buy 10 shares
# 875.81 + sell
# 32.47 + buy 10 shares
# 888.11 + sell
# 24.93 + buy 10 shares
# 890.68 + sell
# 27.11 + buy 10 shares
# 894.30 + sell
# 18.67 + buy 10 shares
# 880.71 + sell
# do nothing
# 25.66 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 865.28 + sell
# 26.93 + buy 10 shares
# do nothing
# 841.99 + sell
# 43.30 + buy 10 shares
# 836.59 + sell
# 33.91 + buy 10 shares
# 818.63 + sell
# do nothing
# 18.23 + buy 10 shares
# do nothing
# 732.81 + sell
# 25.48 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 728.16 + sell
# 22.56 + buy 10 shares
# do nothing
# 743.76 + sell
# 1.23 + buy 10 shares
# 760.37 + sell
# do nothing
# do nothing
# 54.75 + buy 9 shares
# 763.52 + sell
# 42.94 + buy 9 shares
# 768.56 + sell
# 40.71 + buy 9 shares
# 767.25 + sell
# 49.93 + buy 9 shares
# do nothing
# 766.90 + sell
# do nothing
# 45.18 + buy 9 shares
# do nothing
# 787.81 + sell
# 53.94 + buy 9 shares
# 781.97 + sell
# do nothing
# 52.46 + buy 9 shares
# 790.33 + sell
# 58.58 + buy 9 shares
# 792.97 + sell
# 70.56 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 754.52 + sell
# do nothing
# 58.26 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 742.51 + sell
# 51.08 + buy 9 shares
# 755.50 + sell
# 54.93 + buy 9 shares
# 735.91 + sell
# 52.92 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 729.87 + sell
# 64.47 + buy 9 shares
# do nothing
# 734.24 + sell
# 5.56 + buy 10 shares
# 729.58 + sell
# 3.77 + buy 10 shares
# 697.79 + sell
# do nothing
# 33.58 + buy 10 shares
# do nothing
# do nothing
# 678.82 + sell
# 26.86 + buy 10 shares
# 696.05 + sell
# 27.95 + buy 10 shares
# do nothing
# 715.79 + sell
# do nothing
# 28.71 + buy 10 shares
# 722.77 + sell
# do nothing
# 21.15 + buy 10 shares
# 710.92 + sell
# 23.08 + buy 10 shares
# do nothing
# 731.55 + sell
# do nothing
# do nothing
# do nothing
# do nothing
# 31.53 + buy 10 shares
# 765.51 + sell
# 30.83 + buy 10 shares
# do nothing
# 761.54 + sell
# 20.32 + buy 10 shares
# 763.14 + sell
# do nothing
# 32.37 + buy 10 shares
# 779.22 + sell
# 46.34 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 788.26 + sell
# do nothing
# 42.05 + buy 10 shares
# 776.94 + sell
# 25.72 + buy 10 shares
# 751.09 + sell
# 20.25 + buy 10 shares
# 750.52 + sell
# do nothing
# 18.45 + buy 10 shares
# 737.72 + sell
# 10.03 + buy 10 shares
# 734.31 + sell
# 28.03 + buy 10 shares
# do nothing
# 748.52 + sell
# 35.55 + buy 10 shares
# 734.83 + sell
# do nothing
# 29.90 + buy 10 shares
# 774.11 + sell
# 32.27 + buy 10 shares
# 782.92 + sell
# 33.88 + buy 10 shares
# do nothing
# 787.68 + sell
# 41.60 + buy 10 shares
# 784.98 + sell
# 52.43 + buy 10 shares
# 778.92 + sell
# 50.75 + buy 10 shares
# do nothing
# 763.83 + sell
# 45.40 + buy 10 shares
# do nothing
# do nothing
# 773.24 + sell
# 60.62 + buy 10 shares
# 766.47 + sell
# 4.79 + buy 11 shares
# do nothing
# 750.23 + sell
# 47.34 + buy 10 shares
# 742.11 + sell
# 60.43 + buy 10 shares
# 755.97 + sell
# 45.28 + buy 10 shares
# 760.35 + sell
# 53.02 + buy 10 shares
# 762.93 + sell
# 62.11 + buy 10 shares
# do nothing
# 752.04 + sell
# 60.69 + buy 10 shares
# do nothing
# do nothing
# 729.60 + sell
# 6.42 + buy 11 shares
# 726.69 + sell
# 7.49 + buy 11 shares
# do nothing
# 714.12 + sell
# 19.73 + buy 11 shares
# do nothing
# 727.43 + sell
# 23.08 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 592.12 + sell
# 43.94 + buy 10 shares
# 587.46 + sell
# 33.59 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 622.08 + sell
# do nothing
# do nothing
# 46.40 + buy 10 shares
# 651.39 + sell
# 48.21 + buy 10 shares
# 665.50 + sell
# 45.95 + buy 10 shares
# do nothing
# do nothing
# 655.21 + sell
# 59.28 + buy 10 shares
# 655.47 + sell
# 2.22 + buy 11 shares
# do nothing
# do nothing
# 638.89 + sell
# do nothing
# 20.02 + buy 11 shares
# do nothing
# 618.14 + sell
# 29.67 + buy 11 shares
# 642.59 + sell
# 50.97 + buy 11 shares
# 616.71 + sell
# 42.11 + buy 11 shares
# do nothing
# do nothing
# 647.16 + sell
# do nothing
# do nothing
# 13.44 + buy 11 shares
# do nothing
# 645.16 + sell
# 0.28 + buy 11 shares
# do nothing
# do nothing
# 641.23 + sell
# 5.22 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 673.12 + sell
# 4.79 + buy 11 shares
# 660.39 + sell
# 47.62 + buy 10 shares
# do nothing
# do nothing
# 629.32 + sell
# 39.82 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 623.40 + sell
# 39.56 + buy 10 shares
# 610.27 + sell
# do nothing
# 34.01 + buy 10 shares
# do nothing
# do nothing
# 626.15 + sell
# 43.21 + buy 10 shares
# 607.40 + sell
# do nothing
# do nothing
# 0.81 + buy 11 shares
# 610.42 + sell
# 11.08 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 616.96 + sell
# 4.97 + buy 11 shares
# 610.92 + sell
# do nothing
# 6.77 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 585.27 + sell
# do nothing
# 37.55 + buy 10 shares
# do nothing
# do nothing
# 612.05 + sell
# 36.30 + buy 10 shares
# do nothing
# 610.24 + sell
# 39.19 + buy 10 shares
# do nothing
# 607.81 + sell
# 52.11 + buy 10 shares
# 627.23 + sell
# 48.70 + buy 10 shares
# do nothing
# 627.03 + sell
# do nothing
# 53.16 + buy 10 shares
# do nothing
# 669.00 + sell
# 56.57 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 683.95 + sell
# 58.21 + buy 10 shares
# 709.07 + sell
# 51.32 + buy 10 shares
# 717.98 + sell
# 51.32 + buy 10 shares
# do nothing
# 714.07 + sell
# do nothing
# 52.11 + buy 10 shares
# 705.65 + sell
# 45.92 + buy 10 shares
# 707.43 + sell
# do nothing
# 59.15 + buy 10 shares
# 713.28 + sell
# 0.11 + buy 11 shares
# do nothing
# 698.15 + sell
# 59.88 + buy 10 shares
# do nothing
# 721.19 + sell
# 57.38 + buy 10 shares
# 720.53 + sell
# 52.91 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 713.25 + sell
# 38.83 + buy 10 shares
# 725.01 + sell
# 36.19 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 731.88 + sell
# 31.63 + buy 10 shares
# 730.89 + sell
# 27.93 + buy 10 shares
# do nothing
# 730.43 + sell
# 27.74 + buy 10 shares
# 713.78 + sell
# 21.92 + buy 10 shares
# do nothing
# 724.68 + sell
# do nothing
# 13.80 + buy 10 shares
# do nothing
# 719.72 + sell
# 9.04 + buy 10 shares
# do nothing
# 719.92 + sell
# 5.34 + buy 10 shares
# 730.23 + sell
# do nothing
# do nothing
# do nothing
# 2.58 + buy 10 shares
# 740.92 + sell
# 68.53 + buy 9 shares
# do nothing
# do nothing
# 750.95 + sell
# do nothing
# 65.12 + buy 9 shares
# 742.41 + sell
# do nothing
# 64.46 + buy 9 shares
# do nothing
# do nothing
# 752.27 + sell
# 61.30 + buy 9 shares
# do nothing
# 756.57 + sell
# 69.78 + buy 9 shares
# do nothing
# do nothing
# 726.00 + sell
# 69.24 + buy 9 shares
# 734.88 + sell
# 59.89 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 737.09 + sell
# 54.67 + buy 9 shares
# do nothing
# 727.02 + sell
# 55.21 + buy 9 shares
# 731.34 + sell
# 61.03 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 716.11 + sell
# 58.93 + buy 9 shares
# 717.25 + sell
# 56.17 + buy 9 shares
# do nothing
# 741.71 + sell
# 62.95 + buy 9 shares
# do nothing
# do nothing
# 745.37 + sell
# 61.66 + buy 9 shares
# do nothing
# 741.22 + sell
# 62.02 + buy 9 shares
# do nothing
# do nothing
# 733.75 + sell
# do nothing
# 72.61 + buy 9 shares
# do nothing
# 737.91 + sell
# do nothing
# 69.60 + buy 9 shares
# do nothing
# 712.51 + sell
# 68.70 + buy 9 shares
# 713.66 + sell
# 62.02 + buy 9 shares
# do nothing
# do nothing
# 730.50 + sell
# 62.02 + buy 9 shares
# 731.83 + sell
# do nothing
# 57.20 + buy 9 shares
# 734.00 + sell
# 53.72 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 740.39 + sell
# 52.20 + buy 9 shares
# 745.10 + sell
# 59.64 + buy 9 shares
# do nothing
# do nothing
# 754.35 + sell
# 50.15 + buy 9 shares
# 769.65 + sell
# 55.30 + buy 9 shares
# do nothing
# 773.04 + sell
# 55.85 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 788.37 + sell
# 56.27 + buy 9 shares
# 789.27 + sell
# do nothing
# do nothing
# 51.46 + buy 9 shares
# 790.37 + sell
# 54.45 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 781.85 + sell
# 62.06 + buy 9 shares
# 771.68 + sell
# do nothing
# do nothing
# 56.70 + buy 9 shares
# do nothing
# 788.73 + sell
# 57.67 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 790.67 + sell
# 68.57 + buy 9 shares
# 795.85 + sell
# do nothing
# 56.52 + buy 9 shares
# do nothing
# 804.13 + sell
# 65.95 + buy 9 shares
# 783.74 + sell
# do nothing
# 61.31 + buy 9 shares
# 786.25 + sell
# 57.39 + buy 9 shares
# 774.39 + sell
# do nothing
# do nothing
# 1.50 + buy 10 shares
# do nothing
# 777.10 + sell
# 69.59 + buy 9 shares
# 782.30 + sell
# 66.59 + buy 9 shares
# 786.76 + sell
# do nothing
# 78.02 + buy 9 shares
# do nothing
# 804.12 + sell
# 74.97 + buy 9 shares
# do nothing
# 804.86 + sell
# 69.83 + buy 9 shares
# 800.15 + sell
# 62.01 + buy 9 shares
# 799.05 + sell
# 60.30 + buy 9 shares
# 805.34 + sell
# 59.87 + buy 9 shares
# 805.96 + sell
# 70.36 + buy 9 shares
# 807.74 + sell
# 72.32 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 829.28 + sell
# 64.78 + buy 9 shares
# 824.19 + sell
# 65.33 + buy 9 shares
# 828.73 + sell
# 63.30 + buy 9 shares
# 822.59 + sell
# 69.87 + buy 9 shares
# do nothing
# 826.76 + sell
# do nothing
# 71.53 + buy 9 shares
# do nothing
# 817.74 + sell
# 70.91 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 826.70 + sell
# 65.54 + buy 9 shares
# 810.74 + sell
# 62.89 + buy 9 shares
# do nothing
# 800.20 + sell
# do nothing
# do nothing
# 70.28 + buy 9 shares
# do nothing
# 796.44 + sell
# 58.20 + buy 9 shares
# 811.54 + sell
# 57.22 + buy 9 shares
# 819.98 + sell
# 57.65 + buy 9 shares
# 832.74 + sell
# 54.32 + buy 9 shares
# do nothing
# 832.93 + sell
# do nothing
# 45.20 + buy 9 shares
# 830.65 + sell
# 47.73 + buy 9 shares
# do nothing
# do nothing
# 845.58 + sell
# do nothing
# 44.38 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 834.36 + sell
# 38.87 + buy 9 shares
# do nothing
# 823.52 + sell
# 40.29 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 834.86 + sell
# do nothing
# 36.64 + buy 9 shares
# 848.49 + sell
# 35.96 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 850.92 + sell
# 36.83 + buy 9 shares
# do nothing
# 843.89 + sell
# do nothing
# 42.18 + buy 9 shares
# 855.21 + sell
# 40.62 + buy 9 shares
# 856.33 + sell
# 40.50 + buy 9 shares
# 851.47 + sell
# 40.31 + buy 9 shares
# do nothing
# 844.69 + sell
# do nothing
# 54.06 + buy 9 shares
# 838.66 + sell
# 60.03 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 840.98 + sell
# 66.78 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 854.35 + sell
# 79.59 + buy 9 shares
# 851.35 + sell
# do nothing
# 76.78 + buy 9 shares
# do nothing
# 868.47 + sell
# 68.84 + buy 9 shares
# 863.72 + sell
# 63.47 + buy 9 shares
# do nothing
# 873.53 + sell
# 62.47 + buy 9 shares
# do nothing
# 877.90 + sell
# 66.22 + buy 9 shares
# do nothing
# 889.03 + sell
# 62.91 + buy 9 shares
# 889.09 + sell
# 60.97 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 907.66 + sell
# 59.33 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 922.03 + sell
# 56.76 + buy 9 shares
# do nothing
# 921.47 + sell
# 62.60 + buy 9 shares
# do nothing
# do nothing
# 944.31 + sell
# 61.72 + buy 9 shares
# do nothing
# 943.25 + sell
# 61.34 + buy 9 shares
# do nothing
# 948.83 + sell
# 59.46 + buy 9 shares
# 949.77 + sell
# 51.61 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 954.15 + sell
# 54.64 + buy 9 shares
# 953.14 + sell
# 51.99 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 968.91 + sell
# 52.81 + buy 9 shares
# 933.13 + sell
# 43.79 + buy 9 shares
# 910.54 + sell
# 28.96 + buy 9 shares
# 909.09 + sell
# 31.42 + buy 9 shares
# 936.52 + sell
# 38.01 + buy 9 shares
# do nothing
# 937.66 + sell
# 37.00 + buy 9 shares
# 984.04 + sell
# 36.68 + buy 9 shares
# do nothing
# 1009.06 + sell
# 37.70 + buy 9 shares
# do nothing
# do nothing
# 1012.93 + sell
# 51.25 + buy 9 shares
# 994.80 + sell
# 37.82 + buy 9 shares
# do nothing
# 1006.12 + sell
# 32.73 + buy 9 shares
# 993.02 + sell
# 25.93 + buy 9 shares
# 1002.62 + sell
# 22.93 + buy 9 shares
# 985.63 + sell
# 20.96 + buy 9 shares
# do nothing
# do nothing
# 941.73 + sell
# 17.65 + buy 9 shares
# 915.07 + sell
# 10.91 + buy 9 shares
# 931.23 + sell
# 9.06 + buy 9 shares
# 941.35 + sell
# 6.33 + buy 9 shares
# 945.42 + sell
# 102.24 + buy 8 shares
# 938.12 + sell
# 100.32 + buy 8 shares
# 942.48 + sell
# 0.14 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 968.56 + sell
# 105.70 + buy 8 shares
# 978.67 + sell
# do nothing
# 13.13 + buy 9 shares
# 979.76 + sell
# 20.49 + buy 9 shares
# 950.93 + sell
# do nothing
# 26.24 + buy 9 shares
# 970.36 + sell
# 34.68 + buy 9 shares
# 1006.93 + sell
# 61.34 + buy 9 shares
# 1014.28 + sell
# 73.42 + buy 9 shares
# do nothing
# 1006.04 + sell
# 67.54 + buy 9 shares
# 1026.64 + sell
# 65.48 + buy 9 shares
# 1014.55 + sell
# 67.86 + buy 9 shares
# do nothing
# 960.63 + sell
# 58.48 + buy 9 shares
# do nothing
# do nothing
# 934.92 + sell
# 66.19 + buy 9 shares
# 939.74 + sell
# 73.45 + buy 9 shares
# 932.29 + sell
# 1.66 + buy 10 shares
# do nothing
# do nothing
# 984.04 + sell
# 1.16 + buy 10 shares
# do nothing
# 999.83 + sell
# 3.03 + buy 10 shares
# do nothing
# do nothing
# 1026.82 + sell
# 0.23 + buy 10 shares
# 1007.44 + sell
# 10.63 + buy 10 shares
# 1001.63 + sell
# 11.14 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 935.97 + sell
# 16.19 + buy 10 shares
# 926.24 + sell
# 24.55 + buy 10 shares
# do nothing
# 929.55 + sell
# 37.82 + buy 10 shares
# 939.29 + sell
# 13.52 + buy 10 shares
# 943.40 + sell
# 27.36 + buy 10 shares
# do nothing
# 949.10 + sell
# 14.02 + buy 10 shares
# do nothing
# 953.00 + sell
# 24.12 + buy 10 shares
# 946.43 + sell
# do nothing
# 49.08 + buy 10 shares
# 954.29 + sell
# 44.89 + buy 10 shares
# do nothing
# 885.92 + sell
# 75.58 + buy 9 shares
# 3.02 + buy 1 shares
# do nothing
# 698.40 + sell
# do nothing
# 33.27 + buy 10 shares
# 708.48 + sell
# 9.91 + buy 10 shares
# do nothing
# 707.68 + sell
# do nothing
# 26.82 + buy 10 shares
# 698.76 + sell
# 47.56 + buy 10 shares
# do nothing
# 624.41 + sell
# 7.59 + buy 10 shares
# 652.99 + sell
# 64.82 + buy 9 shares
# 5.26 + buy 1 shares
# 665.30 + sell
# 17.59 + buy 10 shares
# do nothing
# 701.13 + sell
# 38.06 + buy 10 shares
# 673.93 + sell
# 36.89 + buy 10 shares
# 653.89 + sell
# 36.67 + buy 10 shares
# 658.71 + sell
# 10.59 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 587.60 + sell
# 34.16 + buy 11 shares
# 663.06 + sell
# 28.04 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 721.32 + sell
# 13.30 + buy 11 shares
# do nothing
# 750.32 + sell
# 31.85 + buy 11 shares
# 754.62 + sell
# 33.39 + buy 11 shares
# 792.13 + sell
# 26.26 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 753.68 + sell
# 25.69 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 792.62 + sell
# 13.96 + buy 11 shares
# do nothing
# do nothing
# 835.24 + sell
# 7.69 + buy 11 shares
# do nothing
# do nothing
# 871.43 + sell
# do nothing
# 78.02 + buy 10 shares
# 894.50 + sell
# 3.09 + buy 11 shares
# 874.28 + sell
# 19.54 + buy 11 shares
# 892.62 + sell
# 44.84 + buy 11 shares
# do nothing
# 941.82 + sell
# 44.67 + buy 11 shares
# 937.24 + sell
# 39.84 + buy 11 shares
# do nothing
# 959.43 + sell
# 38.03 + buy 11 shares
# 965.77 + sell
# do nothing
# 39.68 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 937.29 + sell
# 28.81 + buy 11 shares
# do nothing
# 940.92 + sell
# 30.05 + buy 11 shares
# 953.51 + sell
# 29.22 + buy 11 shares
# do nothing
# 979.43 + sell
# 29.14 + buy 11 shares
# 979.68 + sell
# 21.57 + buy 11 shares
# 979.99 + sell
# do nothing
# 9.67 + buy 11 shares
# do nothing
# 979.91 + sell
# 12.97 + buy 11 shares
# 991.15 + sell
# do nothing
# do nothing
# 1.57 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 894.47 + sell
# 29.14 + buy 11 shares
# do nothing
# do nothing
# 966.21 + sell
# 32.96 + buy 11 shares
# do nothing
# 922.45 + sell
# 46.16 + buy 11 shares
# do nothing
# do nothing
# 985.24 + sell
# 31.80 + buy 11 shares
# 978.65 + sell
# 39.48 + buy 11 shares
# do nothing
# do nothing
# 1027.49 + sell
# 36.56 + buy 11 shares
# 1025.73 + sell
# 36.23 + buy 11 shares
# do nothing
# 1030.99 + sell
# 20.78 + buy 11 shares
# do nothing
# 1091.94 + sell
# do nothing
# 24.98 + buy 11 shares
# 1101.26 + sell
# 26.40 + buy 11 shares
# 1110.41 + sell
# do nothing
# 19.52 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 1109.99 + sell
# 18.60 + buy 11 shares
# do nothing
# 1137.65 + sell
# 20.12 + buy 11 shares
# 1143.13 + sell
# 16.58 + buy 11 shares
# 1117.00 + sell
# 10.26 + buy 11 shares
# do nothing
# do nothing
# 1160.16 + sell
# 12.03 + buy 11 shares
# 1134.45 + sell
# 2.00 + buy 11 shares
# 1128.13 + sell
# do nothing
# 15.99 + buy 11 shares
# 1103.60 + sell
# 16.66 + buy 11 shares
# do nothing
# 1106.53 + sell
# 19.80 + buy 11 shares
# 1103.48 + sell
# 5.65 + buy 11 shares
# do nothing
# 1118.65 + sell
# do nothing
# 9.63 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 1072.57 + sell
# do nothing
# 55.46 + buy 11 shares
# do nothing
# 1077.14 + sell
# 64.18 + buy 11 shares
# 1050.46 + sell
# 50.29 + buy 11 shares
# do nothing
# 1069.18 + sell
# 60.88 + buy 11 shares
# 1071.97 + sell
# 43.43 + buy 11 shares
# do nothing
# do nothing
# 1079.25 + sell
# 23.76 + buy 11 shares
# 1092.11 + sell
# 17.12 + buy 11 shares
# do nothing
# 1073.55 + sell
# 33.89 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 1159.48 + sell
# 34.32 + buy 11 shares
# 1240.02 + sell
# 32.65 + buy 11 shares
# do nothing
# 1248.29 + sell
# 44.70 + buy 11 shares
# 1239.08 + sell
# 59.67 + buy 11 shares
# 1270.83 + sell
# 72.49 + buy 11 shares
# 1251.47 + sell
# 71.63 + buy 11 shares
# 1202.50 + sell
# 58.64 + buy 11 shares
# 1232.48 + sell
# 60.54 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 1284.90 + sell
# 61.75 + buy 11 shares
# do nothing
# 1303.15 + sell
# 54.14 + buy 11 shares
# 1322.44 + sell
# 53.45 + buy 11 shares
# do nothing
# do nothing
# 1279.82 + sell
# 49.88 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 1326.20 + sell
# 44.28 + buy 11 shares
# 1319.02 + sell
# 41.04 + buy 11 shares
# do nothing
# do nothing
# 1350.72 + sell
# 27.81 + buy 11 shares
# 1360.01 + sell
# 17.83 + buy 11 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 1386.65 + sell
# 23.55 + buy 11 shares
# 1397.56 + sell
# 23.55 + buy 11 shares
# 1403.10 + sell
# 37.53 + buy 11 shares
# do nothing
# 1411.72 + sell
# 32.78 + buy 11 shares
# 1421.66 + sell
# 27.15 + buy 11 shares
# do nothing
# do nothing
# 1490.10 + sell
# 36.65 + buy 11 shares
# 1474.53 + sell
# 28.74 + buy 11 shares
# do nothing
# do nothing
# do nothing
# 1522.69 + sell
# do nothing
# 31.74 + buy 11 shares
# do nothing
# do nothing
# 1527.28 + sell
# 27.32 + buy 11 shares
# do nothing
# do nothing
# 1495.00 + sell
# do nothing
# 12.55 + buy 11 shares
# do nothing
# 1500.45 + sell
# 29.88 + buy 11 shares
# do nothing
# do nothing
# 1537.96 + sell
# 8.82 + buy 11 shares
# 1565.33 + sell
# 1.71 + buy 11 shares
# 1632.61 + sell
# 139.17 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1640.65 + sell
# 131.29 + buy 10 shares
# 1644.47 + sell
# 120.81 + buy 10 shares
# do nothing
# 1640.83 + sell
# 131.74 + buy 10 shares
# 1637.65 + sell
# 124.32 + buy 10 shares
# 1628.26 + sell
# 101.88 + buy 10 shares
# 1626.55 + sell
# 94.79 + buy 10 shares
# 1618.64 + sell
# 85.81 + buy 10 shares
# do nothing
# 1628.84 + sell
# 82.06 + buy 10 shares
# 1658.21 + sell
# 71.78 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 1658.27 + sell
# 61.04 + buy 10 shares
# do nothing
# 1690.93 + sell
# 64.00 + buy 10 shares
# do nothing
# do nothing
# 1680.64 + sell
# 88.96 + buy 10 shares
# do nothing
# 1704.52 + sell
# 70.43 + buy 10 shares
# do nothing
# 1752.04 + sell
# 72.24 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1784.41 + sell
# 74.13 + buy 10 shares
# 1728.93 + sell
# 53.51 + buy 10 shares
# do nothing
# 1760.48 + sell
# 58.23 + buy 10 shares
# do nothing
# 1808.76 + sell
# 64.20 + buy 10 shares
# 1782.59 + sell
# 57.08 + buy 10 shares
# do nothing
# 1803.93 + sell
# 66.89 + buy 10 shares
# 1777.98 + sell
# 60.74 + buy 10 shares
# do nothing
# do nothing
# 1804.27 + sell
# do nothing
# 47.76 + buy 10 shares
# do nothing
# 1794.45 + sell
# 47.43 + buy 10 shares
# do nothing
# do nothing
# 1764.50 + sell
# 43.83 + buy 10 shares
# do nothing
# 1778.12 + sell
# 24.69 + buy 10 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 1780.63 + sell
# 39.07 + buy 10 shares
# do nothing
# 1672.47 + sell
# 37.90 + buy 10 shares
# 1666.11 + sell
# 21.60 + buy 10 shares
# do nothing
# do nothing
# 1650.89 + sell
# 24.20 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1769.69 + sell
# 48.57 + buy 10 shares
# do nothing
# do nothing
# 1807.34 + sell
# 46.55 + buy 10 shares
# do nothing
# 1776.33 + sell
# 80.08 + buy 10 shares
# do nothing
# 1814.57 + sell
# 61.57 + buy 10 shares
# do nothing
# 1763.52 + sell
# 83.03 + buy 10 shares
# do nothing
# do nothing
# 1693.37 + sell
# 107.38 + buy 10 shares
# 1711.45 + sell
# do nothing
# 87.85 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1825.26 + sell
# 75.79 + buy 10 shares
# 1860.78 + sell
# 85.39 + buy 10 shares
# 1833.16 + sell
# 83.94 + buy 10 shares
# 1829.77 + sell
# 63.72 + buy 10 shares
# do nothing
# do nothing
# 1843.82 + sell
# do nothing
# 43.48 + buy 10 shares
# 1891.64 + sell
# 45.36 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1866.36 + sell
# 46.05 + buy 10 shares
# 1910.15 + sell
# 56.26 + buy 10 shares
# do nothing
# do nothing
# 1912.81 + sell
# 60.72 + buy 10 shares
# do nothing
# do nothing
# 1897.36 + sell
# 52.91 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1949.80 + sell
# 46.91 + buy 10 shares
# 1988.86 + sell
# 33.95 + buy 10 shares
# 1970.94 + sell
# 41.02 + buy 10 shares
# 1985.70 + sell
# 29.46 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 1987.08 + sell
# 34.55 + buy 10 shares
# 1999.78 + sell
# 33.25 + buy 10 shares
# 2013.33 + sell
# 36.79 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 2072.66 + sell
# 31.07 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 2099.63 + sell
# 32.37 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 2113.93 + sell
# 27.52 + buy 10 shares
# 2123.47 + sell
# 29.34 + buy 10 shares
# 2145.06 + sell
# 36.10 + buy 10 shares
# 2150.38 + sell
# 18.50 + buy 10 shares
# do nothing
# do nothing
# do nothing
# 2133.39 + sell
# 16.84 + buy 10 shares
# 2155.52 + sell
# 24.51 + buy 10 shares
# do nothing
# 2168.59 + sell
# 17.19 + buy 10 shares
# 2188.72 + sell
# 9.87 + buy 10 shares
# do nothing
# 2271.78 + sell
# 222.74 + buy 9 shares
# 2315.28 + sell
# 216.44 + buy 9 shares
# 2386.29 + sell
# 211.53 + buy 9 shares
# 2398.81 + sell
# 197.27 + buy 9 shares
# 2418.53 + sell
# 179.21 + buy 9 shares
# 2342.01 + sell
# 178.57 + buy 9 shares
# do nothing
# do nothing
# 2356.98 + sell
# 176.21 + buy 9 shares
# do nothing
# do nothing
# 2269.50 + sell
# 180.82 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# 2436.82 + sell
# 171.16 + buy 9 shares
# 2452.64 + sell
# 172.12 + buy 9 shares
# do nothing
# do nothing
# 2474.21 + sell
# 176.59 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 2344.97 + sell
# 153.96 + buy 9 shares
# do nothing
# 2255.49 + sell
# 148.87 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 2363.66 + sell
# 124.74 + buy 9 shares
# do nothing
# 2433.19 + sell
# 169.17 + buy 9 shares
# 2491.32 + sell
# 163.01 + buy 9 shares
# 2497.40 + sell
# 166.25 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 2604.71 + sell
# 155.33 + buy 9 shares
# 2615.79 + sell
# 159.81 + buy 9 shares
# 2472.73 + sell
# 153.70 + buy 9 shares
# do nothing
# 2490.82 + sell
# 137.24 + buy 9 shares
# 2532.77 + sell
# 106.45 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 2853.37 + sell
# 121.09 + buy 9 shares
# do nothing
# 2903.87 + sell
# 132.52 + buy 9 shares
# 2704.01 + sell
# 141.98 + buy 9 shares
# do nothing
# 2335.44 + sell
# 68.35 + buy 9 shares
# do nothing
# 2579.50 + sell
# 72.98 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 2747.42 + sell
# 81.79 + buy 9 shares
# do nothing
# do nothing
# 2902.72 + sell
# 53.20 + buy 9 shares
# 2912.69 + sell
# 24.53 + buy 9 shares
# 2894.58 + sell
# 47.97 + buy 9 shares
# do nothing
# 2901.30 + sell
# do nothing
# do nothing
# 26.27 + buy 9 shares
# 2779.25 + sell
# 54.97 + buy 9 shares
# do nothing
# do nothing
# 3115.54 + sell
# 55.97 + buy 9 shares
# 3139.41 + sell
# 51.13 + buy 9 shares
# do nothing
# do nothing
# 3215.07 + sell
# do nothing
# 62.86 + buy 9 shares
# 3352.56 + sell
# 65.71 + buy 9 shares
# 3269.03 + sell
# 82.22 + buy 9 shares
# 3320.81 + sell
# 125.12 + buy 9 shares
# 3615.31 + sell
# 150.67 + buy 9 shares
# 3659.27 + sell
# 128.31 + buy 9 shares
# do nothing
# 3696.42 + sell
# 148.23 + buy 9 shares
# do nothing
# 3716.47 + sell
# 152.53 + buy 9 shares
# do nothing
# 3884.20 + sell
# 150.93 + buy 9 shares
# do nothing
# do nothing
# 3922.07 + sell
# 187.67 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 4057.44 + sell
# 221.34 + buy 9 shares
# 4253.79 + sell
# 197.99 + buy 9 shares
# do nothing
# do nothing
# 4026.91 + sell
# 247.30 + buy 9 shares
# 4069.23 + sell
# do nothing
# 336.55 + buy 9 shares
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# do nothing
# 3544.62 + sell
# do nothing
# 310.98 + buy 9 shares
# 3903.26 + sell
# 310.98 + buy 9 shares
# do nothing
# 3716.97 + sell
# 336.89 + buy 9 shares
# 3712.01 + sell
# 4.46 + buy 10 shares
# do nothing
# 3649.94 + sell
# 23.93 + buy 10 shares
# 3693.27 + sell
# 116.01 + buy 10 shares
# do nothing
# do nothing
# 3929.16 + sell
# 177.37 + buy 10 shares
# do nothing
# 4013.88 + sell
# 175.93 + buy 10 shares
# 4131.69 + sell
# 163.09 + buy 10 shares
# do nothing
# 3894.91 + sell
# 97.61 + buy 10 shares
# 4040.37 + sell
# 113.68 + buy 10 shares
# do nothing
# 4223.69 + sell
# 104.73 + buy 10 shares
# do nothing
# 4491.76 + sell
# 92.76 + buy 10 shares
# 4492.44 + sell
# 121.92 + buy 10 shares
# 4530.98 + sell
# 183.26 + buy 10 shares
# do nothing
# 4269.68 + sell
# 153.50 + buy 10 shares
# 4382.70 + sell
# 179.28 + buy 10 shares
# 4361.76 + sell
# 135.28 + buy 10 shares
# do nothing
# 4340.44 + sell
# 69.66 + buy 10 shares
# do nothing
# 4477.59 + sell
# 36.02 + buy 10 shares
# do nothing
# 4583.67 + sell
# 29.79 + buy 10 shares
# 4667.08 + sell
# 441.49 + buy 9 shares
# do nothing
# do nothing
# 4996.51 + sell
# 438.95 + buy 9 shares
# do nothing
# 4862.70 + sell
# 397.04 + buy 9 shares
# do nothing
# do nothing
# 5094.65 + sell
# 402.75 + buy 9 shares
# do nothing
# do nothing
# do nothing
# 5323.89 + sell
# 402.31 + buy 9 shares
# 5426.52 + sell
# 389.75 + buy 9 shares
# 5669.84 + sell
# 423.70 + buy 9 shares
# do nothing
# 5653.25 + sell
# 503.55 + buy 9 shares
# 5883.46 + sell
# 474.18 + buy 9 shares
# 5883.02 + sell
# 458.30 + buy 9 shares
# do nothing
# 5566.46 + sell
# 446.02 + buy 9 shares
# 5310.47 + sell
# 410.88 + buy 9 shares
# do nothing
# do nothing
# 6023.01 + sell
# 363.13 + buy 9 shares
# do nothing
# 6034.97 + sell
# do nothing
# 301.38 + buy 9 shares
# 6077.54 + sell
# 287.19 + buy 9 shares
# 6222.28 + sell
# 306.07 + buy 9 shares
# do nothing
# 6245.37 + sell
# 283.70 + buy 9 shares
# do nothing
# 6127.60 + sell
# 194.03 + buy 9 shares
# do nothing
# do nothing
# 6390.52 + sell
# 194.66 + buy 9 shares
# do nothing
# 6421.58 + sell
# 225.26 + buy 9 shares
# do nothing
# do nothing
# do nothing
